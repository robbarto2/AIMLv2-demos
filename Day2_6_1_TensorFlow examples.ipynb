# %%
import numpy as np
import tensorflow as tf

# Sample data
X = np.array([1, 2, 3, 4], dtype=float)
y = np.array([2, 4, 6, 8], dtype=float)

# Define a simple linear model
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=100)

# Predict
print(model.predict([5.0]))
# Out:
# 2023-08-29 14:25:36.122364: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 2023-08-29 14:25:54.646409: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 0s 208ms/step - loss: 19.9503
# Epoch 2/100
# 1/1 [==============================] - 0s 3ms/step - loss: 13.8555
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6264
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6918
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6554
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2424
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2619
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5814
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1092
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7815
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5540
# Epoch 12/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3961
# Epoch 13/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2864
# Epoch 14/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2103
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1574
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1206
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0950
# Epoch 18/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0772
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0647
# Epoch 20/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0560
# Epoch 21/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0499
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0456
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 24/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0404
# Epoch 25/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0388
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0377
# Epoch 27/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0368
# Epoch 28/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0361
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0356
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 31/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0348
# Epoch 32/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0345
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0342
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 35/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0338
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0335
# Epoch 37/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0333
# Epoch 38/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0331
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 40/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0327
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0325
# Epoch 42/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0321
# Epoch 44/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0319
# Epoch 45/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0317
# Epoch 46/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0315
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0313
# Epoch 48/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0311
# Epoch 49/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0310
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0308
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0306
# Epoch 52/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0304
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 54/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0300
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0299
# Epoch 56/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0297
# Epoch 57/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0295
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0293
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0292
# Epoch 60/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0290
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 62/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0285
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0283
# Epoch 65/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0281
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0280
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0278
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0276
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0275
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0273
# Epoch 71/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0271
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 73/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0268
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0267
# Epoch 75/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0265
# Epoch 76/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 77/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0262
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0260
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0259
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0257
# Epoch 81/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0256
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0254
# Epoch 83/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0253
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0251
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0249
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0248
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0247
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0245
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0244
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0242
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0241
# Epoch 92/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0239
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0238
# Epoch 94/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0236
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0235
# Epoch 96/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0234
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 98/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0231
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0229
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0228
# 1/1 [==============================] - 0s 65ms/step
# [[9.741895]]

# %%
# Predict
predictions = model.predict(X)

import matplotlib.pyplot as plt
# Plot
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, predictions, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('TensorFlow Linear Regression')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
#Example where pythorch is easier

# %%
import time
start_time = time.time()
import tensorflow as tf

# Sample data
X = tf.Variable([[1.], [2.], [3.], [4.]])
y = 2 * X + 1

# Simple linear model
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=(1,))])
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
loss_fn = tf.keras.losses.MSE

# Custom training loop
num_epochs = 100
loss_threshold = 0.1
for epoch in range(num_epochs):
    with tf.GradientTape() as tape:
        outputs = model(X)
        loss = loss_fn(y, outputs)
    
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    # Dynamic data modification based on loss
 
    if tf.reduce_mean(loss) < loss_threshold:
        X.assign(X * 1.5)

    # Print loss every 20 epochs
    if epoch % 20 == 0:
        scalar_loss = tf.reduce_mean(loss).numpy()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {scalar_loss:.4f}')

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Execution time: {elapsed_time:.2f} seconds")
# Out:
# Epoch [1/100], Loss: 7.5739
# Epoch [21/100], Loss: 6212158.0000
# Epoch [41/100], Loss: 52338495108555997184.0000
# Epoch [61/100], Loss: 440960857235537385169912040783872.0000
# Epoch [81/100], Loss: inf
# Execution time: 0.29 seconds
